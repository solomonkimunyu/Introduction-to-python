# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
pwd
# Out:
# '/root/Supervised leanring/Basic python and modules'

# %%
house=pd.read_csv('/root/data/house_sales.csv')

# %%
sns.boxplot(x='bedrooms',y='price',data=house)

# %%
sns.distplot(house['price'],color='red')

# %%
sns.scatterplot(x='sqft_living',y='price',data=house)

# %%
sns.lmplot(x='sqft_living',y='price',data=house)

# %%
house.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
X=house[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','grade','sqft_above','sqft_above','sqft_basement','yr_built','yr_renovated','zipcode','lat','long','sqft_living15','sqft_lot15']]
y=house['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (15129, 19) (6484, 19) (15129,) (6484,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=model.predict(X_test)

# %%
#Lets visualize with a boxplot
house.boxplot('price')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cars = pd.read_csv('/root/data/auto-mpg.csv')

# %%
y1 = cars['mpg']

# %%
x = range(50)
max(cars['horsepower'])
x
# Out:
# range(0, 50)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
x1 = np.arange(1,400)
plt.plot(x)

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
y = cars['horsepower']
y1 = cars['displacement']

# %%
x = np.arange(1,50)
x1 = range(0,50)

# %%
plt.plot(y)

# %%
y = cars['weight']

# %%
cars.plot()

# %%
cars['weight'].plot()

# %%
plt.plot('weight', 'horsepower',data=cars)

# %%
plt.plot('displacement', data=cars)
plt.plot('horsepower', data=cars)
plt.xlabel('Range')
plt.ylabel('hp and disp')
plt.legend()

# %%
plt.stackplot('displacement','horsepower',  data=cars)
plt.stackplot('horsepower', data=cars)
plt.xlabel('Range')
plt.ylabel('hp and disp')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-04a68a4f2bdd> in <module>
#       1 plt.stackplot('displacement','horsepower',  data=cars)
# ----> 2 plt.stackplot('horsepower', data=cars)
#       3 plt.xlabel('Range')
#       4 plt.ylabel('hp and disp')
#       5 plt.legend()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in stackplot(x, labels, colors, baseline, data, *args, **kwargs)
#    2898     return gca().stackplot(
#    2899         x, *args, labels=labels, colors=colors, baseline=baseline,
# -> 2900         **({"data": data} if data is not None else {}), **kwargs)
#    2901
#    2902
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1637                 bound.arguments.setdefault(varkwargs_name, {})["label"] = label
#    1638
# ...

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %%
plt.plot(x, x)
plt.plot(x, x**2)
plt.plot(x, x**3)
plt.plot(x, x**4)

# %%
x = np.arange(1,10)
plt.stackplot(x, x**3)
plt.stackplot(x, x**2.5, linewidth=5, color='g', alpha=0.5)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
a = cars['cylinders']
b = range(0,15)
plt.bar(a,b)

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# which you would then use as:

data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': 'x'})

# %% [raw]
# def plotter(x,y,ax,param_dict):
#     out = ax.plot(x, y, param_dict)
#     return out
# x, y = np.random.randn(0,100)
# fig, ax = plt.subplot(1,1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['path.simplify_threshold'] = 1.0

# Setup, and create the data to plot
y = np.random.rand(100000)
y[50000:] *= 2
y[np.logspace(1,np.log10(50000), 400).astype(int)] = -1
mpl.rcParams['path.simplify'] = True

mpl.rcParams['agg.path.chunksize'] = 0
plt.plot(y)
plt.show()

mpl.rcParams['agg.path.chunksize'] = 10000
plt.plot(y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
x = (4,2,5,1,6,7)
y = (4,6,8,6,7,5)
x1 = (5,6,7,4,6,9)
y1 = (5,6,7,1,5,2)
index = np.arange(5)

plt.bar(x,y)
plt.bar(x1, y1)
# Out:
# <BarContainer object of 6 artists>

# %%
# Out:
# array([0, 1, 2, 3, 4])
